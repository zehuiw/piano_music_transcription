# %%
import os

# %%
os.listdir('.')
# Out:
# ['AkPnStgb',
#  '.DS_Store',
#  'Untitled.ipynb',
#  'AkPnCGdD',
#  '.ipynb_checkpoints',
#  'StbgTGd2',
#  'SptkBGCl']

# %%
for root, subdir, files in os.walk('.'):
    print "------------------------------iter---------------"
    print root
    print 'subdir-----', subdir
    print 'files ----', files
    for f in files:
        print os.path.join(root, f)
# Out:
# ------------------------------iter---------------
# .
# subdir----- ['AkPnStgb', 'AkPnCGdD', '.ipynb_checkpoints', 'StbgTGd2', 'SptkBGCl']
# files ---- ['.DS_Store', 'Untitled.ipynb']
# ./.DS_Store
# ./Untitled.ipynb
# ------------------------------iter---------------
# ./AkPnStgb
# subdir----- ['MUS']
# files ---- ['.DS_Store']
# ./AkPnStgb/.DS_Store
# ------------------------------iter---------------
# ./AkPnStgb/MUS
# subdir----- []
# ...

# %%
a = "./aa/bb.xtx"
os.path.splitext(a)
# Out:
# ('./aa/bb', '.xtx')
